# %% [markdown]
# # Clustering
#
# - Clustering can be defined as grouping unlabelled data.
# - It falls under unsupervised Machine Learning.
#
#
# Clustering is an unsupervised machine learning technique designed to group unlabeled examples based on their similarity to each other.

# %% [markdown]
# ![WhatsApp Image 2024-11-02 at 5.26.23 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Clustering can group the items based on their similarity.

# %% [markdown]
# ![WhatsApp Image 2024-11-02 at 5.26.25 PM.jpeg](data:image/jpeg;base64,...)
